# %%
import pandas as pd

# %%
df_pathogenDomains = pd.read_csv(r'C:\Users\91956\OneDrive\Desktop\bacteria pathogen domains.csv', low_memory = False)

# %%
df_pathogenDomains
# Out:
#       Pathogen ID  PSSM-ID    Short name
# 0          Q5ZWZ3   408423  LidA_Long_CC
# 1          Q5ZWZ3   224117           Smc
# 2          Q5ZWZ3   237177      PRK12704
# 3          Q5ZWZ3   235175      PRK03918
# 4          Q5ZWZ3   411490   pneumo_PspA
# ...           ...      ...           ...
# 40407      Q6RCR0   235175      PRK03918
# 40408      Q6RCR0   224117           Smc
# 40409      Q6RCR0   227278          EnvC
# 40410      Q6RCR0   178768      PLN03229
# 40411      Q6RCR0   129694         rad50
#
# [40412 rows x 3 columns]

# %%
df_interactorDomains = pd.read_csv(r'C:\Users\91956\OneDrive\Desktop\host interactor domains.csv', low_memory = False)

# %%
df_interactions =  pd.read_csv(r'C:\Users\91956\OneDrive\Desktop\bacteria interactions.csv', low_memory = False)

# %%
df_interactions
# Out:
#           Host ID                                      Pathogen Name  \
# 0          P62820  Legionella pneumophila subsp. pneumophila (str...
# 1          P60953                   Mycobacterium avium (strain 104)
# 2          P60953                   Mycobacterium avium (strain 104)
# 3          P60953                   Mycobacterium avium (strain 104)
# 4          P08603                Streptococcus pyogenes serotype M49
# ...           ...                                                ...
# 10061      P19013  Streptococcus agalactiae serotype III (strain ...
# 10062      E9KL35                        Yersinia pseudotuberculosis
# 10063  A0A0U2ZQU7  Listeria monocytogenes serotype 1/2a (strain 1...
# 10064  A0A0S2Z491  Bordetella bronchiseptica (strain ATCC BAA-588...
# 10065      P62987                             Legionella pneumophila
#
#       Pathogen ID
# 0          Q5ZWZ3
# 1      A0A0H2ZTM2
# 2      A0A0H3A2T3
# 3      A0A0H3A1L5
# 4          P16946
# ...           ...
# 10061      Q8E473
# 10062      Q56935
# 10063      G2K3G6
# 10064  A0A0H3LYM0
# 10065      Q6RCR0
#
# [10066 rows x 3 columns]

# %%
df_hostInteractors = pd.read_csv(r'C:\Users\91956\OneDrive\Desktop\host interactors.csv', low_memory = False)

# %%
df_pathogenDomains = df_pathogenDomains.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
df_interactions = df_interactions.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
df_hostInteractors = df_hostInteractors.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
df_interactorDomains = df_interactorDomains.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
df_interactions_pathogenDomains = df_interactions.merge(df_pathogenDomains,how = 'left',left_on = 'Pathogen ID',right_on = 'Pathogen ID')

# %%
df_interactions_hostInteractors = df_interactions_pathogenDomains.merge(df_hostInteractors,how = 'left',left_on = 'Host ID',right_on = 'Entry')

# %%
df_interactions_hostInteractors
# Out:
#         Host ID                                      Pathogen Name  \
# 0        P62820  Legionella pneumophila subsp. pneumophila (str...
# 1        P62820  Legionella pneumophila subsp. pneumophila (str...
# 2        P62820  Legionella pneumophila subsp. pneumophila (str...
# 3        P62820  Legionella pneumophila subsp. pneumophila (str...
# 4        P62820  Legionella pneumophila subsp. pneumophila (str...
# ...         ...                                                ...
# 2437589  P62987                             Legionella pneumophila
# 2437590  P62987                             Legionella pneumophila
# 2437591  P62987                             Legionella pneumophila
# 2437592  P62987                             Legionella pneumophila
# 2437593  P62987                             Legionella pneumophila
#
#         Pathogen ID   PSSM-ID    Short name   Entry Interactor ID
# 0            Q5ZWZ3  408423.0  LidA_Long_CC  P62820        Q96LT7
# 1            Q5ZWZ3  408423.0  LidA_Long_CC  P62820        P31150
# 2            Q5ZWZ3  408423.0  LidA_Long_CC  P62820        P42345
# 3            Q5ZWZ3  408423.0  LidA_Long_CC  P62820        Q01968
# 4            Q5ZWZ3  408423.0  LidA_Long_CC  P62820        P47224
# ...             ...       ...           ...     ...           ...
# 2437589      Q6RCR0  129694.0         rad50  P62987        Q9Y3C5
# 2437590      Q6RCR0  129694.0         rad50  P62987        P37840
# 2437591      Q6RCR0  129694.0         rad50  P62987        Q86VP1
# 2437592      Q6RCR0  129694.0         rad50  P62987        Q9UMX0
# 2437593      Q6RCR0  129694.0         rad50  P62987        Q9UHD9
#
# [2437594 rows x 7 columns]

# %%
df_interactions_hostInteractors = df_interactions_hostInteractors.drop_duplicates()
df_interactions_hostInteractors = df_interactions_hostInteractors.dropna()

# %%
df_interactions_hostInteractors
# Out:
#         Host ID                                      Pathogen Name  \
# 0        P62820  Legionella pneumophila subsp. pneumophila (str...
# 1        P62820  Legionella pneumophila subsp. pneumophila (str...
# 2        P62820  Legionella pneumophila subsp. pneumophila (str...
# 3        P62820  Legionella pneumophila subsp. pneumophila (str...
# 4        P62820  Legionella pneumophila subsp. pneumophila (str...
# ...         ...                                                ...
# 2437589  P62987                             Legionella pneumophila
# 2437590  P62987                             Legionella pneumophila
# 2437591  P62987                             Legionella pneumophila
# 2437592  P62987                             Legionella pneumophila
# 2437593  P62987                             Legionella pneumophila
#
#         Pathogen ID   PSSM-ID    Short name   Entry Interactor ID
# 0            Q5ZWZ3  408423.0  LidA_Long_CC  P62820        Q96LT7
# 1            Q5ZWZ3  408423.0  LidA_Long_CC  P62820        P31150
# 2            Q5ZWZ3  408423.0  LidA_Long_CC  P62820        P42345
# 3            Q5ZWZ3  408423.0  LidA_Long_CC  P62820        Q01968
# 4            Q5ZWZ3  408423.0  LidA_Long_CC  P62820        P47224
# ...             ...       ...           ...     ...           ...
# 2437589      Q6RCR0  129694.0         rad50  P62987        Q9Y3C5
# 2437590      Q6RCR0  129694.0         rad50  P62987        P37840
# 2437591      Q6RCR0  129694.0         rad50  P62987        Q86VP1
# 2437592      Q6RCR0  129694.0         rad50  P62987        Q9UMX0
# 2437593      Q6RCR0  129694.0         rad50  P62987        Q9UHD9
#
# [2331650 rows x 7 columns]

# %%
df_interactions_interactors = df_interactions_hostInteractors.merge(df_interactorDomains,how = 'left',left_on = 'Interactor ID',right_on = 'Interactor ID')

# %%
df_interactions_interactors
# Out:
#          Host ID                                      Pathogen Name  \
# 0         P62820  Legionella pneumophila subsp. pneumophila (str...
# 1         P62820  Legionella pneumophila subsp. pneumophila (str...
# 2         P62820  Legionella pneumophila subsp. pneumophila (str...
# 3         P62820  Legionella pneumophila subsp. pneumophila (str...
# 4         P62820  Legionella pneumophila subsp. pneumophila (str...
# ...          ...                                                ...
# 18784607  P62987                             Legionella pneumophila
# 18784608  P62987                             Legionella pneumophila
# 18784609  P62987                             Legionella pneumophila
# 18784610  P62987                             Legionella pneumophila
# 18784611  P62987                             Legionella pneumophila
#
#          Pathogen ID  PSSM-ID_x  Short name_x   Entry Interactor ID  \
# 0             Q5ZWZ3   408423.0  LidA_Long_CC  P62820        Q96LT7
# 1             Q5ZWZ3   408423.0  LidA_Long_CC  P62820        P31150
# 2             Q5ZWZ3   408423.0  LidA_Long_CC  P62820        P42345
# 3             Q5ZWZ3   408423.0  LidA_Long_CC  P62820        Q01968
# 4             Q5ZWZ3   408423.0  LidA_Long_CC  P62820        P47224
# ...              ...        ...           ...     ...           ...
# 18784607      Q6RCR0   129694.0         rad50  P62987        Q9Y3C5
# 18784608      Q6RCR0   129694.0         rad50  P62987        P37840
# 18784609      Q6RCR0   129694.0         rad50  P62987        Q86VP1
# 18784610      Q6RCR0   129694.0         rad50  P62987        Q9UMX0
# 18784611      Q6RCR0   129694.0         rad50  P62987        Q9UHD9
#
#           PSSM-ID_y Short name_y
# 0               NaN          NaN
# 1               NaN          NaN
# 2               NaN          NaN
# 3               NaN          NaN
# 4               NaN          NaN
# ...             ...          ...
# 18784607        NaN          NaN
# 18784608        NaN          NaN
# 18784609        NaN          NaN
# 18784610        NaN          NaN
# 18784611        NaN          NaN
#
# [18784612 rows x 9 columns]

# %%
df_interactions_interactors = df_interactions_interactors.drop_duplicates()

# %%
df_interactions_interactors
# Out:
#          Host ID                                      Pathogen Name  \
# 0         P62820  Legionella pneumophila subsp. pneumophila (str...
# 1         P62820  Legionella pneumophila subsp. pneumophila (str...
# 2         P62820  Legionella pneumophila subsp. pneumophila (str...
# 3         P62820  Legionella pneumophila subsp. pneumophila (str...
# 4         P62820  Legionella pneumophila subsp. pneumophila (str...
# ...          ...                                                ...
# 18784607  P62987                             Legionella pneumophila
# 18784608  P62987                             Legionella pneumophila
# 18784609  P62987                             Legionella pneumophila
# 18784610  P62987                             Legionella pneumophila
# 18784611  P62987                             Legionella pneumophila
#
#          Pathogen ID  PSSM-ID_x  Short name_x   Entry Interactor ID  \
# 0             Q5ZWZ3   408423.0  LidA_Long_CC  P62820        Q96LT7
# 1             Q5ZWZ3   408423.0  LidA_Long_CC  P62820        P31150
# 2             Q5ZWZ3   408423.0  LidA_Long_CC  P62820        P42345
# 3             Q5ZWZ3   408423.0  LidA_Long_CC  P62820        Q01968
# 4             Q5ZWZ3   408423.0  LidA_Long_CC  P62820        P47224
# ...              ...        ...           ...     ...           ...
# 18784607      Q6RCR0   129694.0         rad50  P62987        Q9Y3C5
# 18784608      Q6RCR0   129694.0         rad50  P62987        P37840
# 18784609      Q6RCR0   129694.0         rad50  P62987        Q86VP1
# 18784610      Q6RCR0   129694.0         rad50  P62987        Q9UMX0
# 18784611      Q6RCR0   129694.0         rad50  P62987        Q9UHD9
#
#           PSSM-ID_y Short name_y
# 0               NaN          NaN
# 1               NaN          NaN
# 2               NaN          NaN
# 3               NaN          NaN
# 4               NaN          NaN
# ...             ...          ...
# 18784607        NaN          NaN
# 18784608        NaN          NaN
# 18784609        NaN          NaN
# 18784610        NaN          NaN
# 18784611        NaN          NaN
#
# [18784612 rows x 9 columns]

# %%
df_interactions_interactors = df_interactions_interactors.dropna()

# %%
df_host_pathogen_domains = df_interactions_interactors[(df_interactions_interactors['PSSM-ID_x'].isnull() == False) & (df_interactions_interactors['PSSM-ID_y'].isnull() == False) ]

# %%
df_host_pathogen_domains[df_interactions_interactors['PSSM-ID_x'] == df_interactions_interactors['PSSM-ID_y']]
# Out:
#          Host ID            Pathogen Name Pathogen ID  PSSM-ID_x  \
# 739664    Q16539          Yersinia pestis      Q8ZBC2   235401.0
# 743823    Q16539          Yersinia pestis      Q8ZBC2   223606.0
# 745906    Q16539          Yersinia pestis      Q8ZBC2   177089.0
# 747975    Q16539          Yersinia pestis      Q8ZBC2   206674.0
# 764590    Q16539          Yersinia pestis      Q8ZBC2   206647.0
# ...          ...                      ...         ...        ...
# 18384024  Q15418  Yersinia enterocolitica      Q93KU8   411101.0
# 18384066  Q15418  Yersinia enterocolitica      Q93KU8   215633.0
# 18384084  Q15418  Yersinia enterocolitica      Q93KU8   380193.0
# 18384157  Q15418  Yersinia enterocolitica      Q93KU8   238064.0
# 18384208  Q15418  Yersinia enterocolitica      Q93KU8   215061.0
#
#                     Short name_x   Entry Interactor ID  PSSM-ID_y  \
# 739664                      infB  Q16539        P68104   235401.0
# 743823                      InfB  Q16539        P68104   223606.0
# 745906                      infB  Q16539        P68104   177089.0
# 747975                 IF2_eIF5B  Q16539        P68104   206674.0
# 764590    GTP_translation_factor  Q16539        P68104   206647.0
# ...                          ...     ...           ...        ...
# 18384024         inl_like_NEAT_1  Q15418        Q14160   411101.0
# 18384066                PLN03210  Q15418        Q14160   215633.0
# 18384084            internalin_A  Q15418        Q14160   380193.0
# 18384157                  LRR_RI  Q15418        Q14160   238064.0
# 18384208                PLN00113  Q15418        Q14160   215061.0
#
#                     Short name_y
# 739664                      infB
# 743823                      InfB
# 745906                      infB
# 747975                 IF2_eIF5B
# 764590    GTP_translation_factor
# ...                          ...
# 18384024         inl_like_NEAT_1
# 18384066                PLN03210
# 18384084            internalin_A
# 18384157                  LRR_RI
# 18384208                PLN00113
#
# [721 rows x 9 columns]

# %%
df_interactions_interactors = df_interactions_interactors.drop_duplicates()

# %%
df_host_pathogen_domains[df_interactions_interactors['PSSM-ID_x'] == df_interactions_interactors['PSSM-ID_y']].to_csv('./Downloads/bacteria_DMPs.csv')
